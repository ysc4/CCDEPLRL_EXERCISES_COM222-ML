# %% [markdown]
# <a href="https://colab.research.google.com/github/robitussin/CCDEPLRL_EXERCISES/blob/main/exercise4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exercise 4

# %% [markdown]
# ## Instructions
#
#
# 1. Collect **100-200 images** of the fruit
# 2. Split the collected images for train, test and validation. Please make sure that there are no duplicate images. Images that are used in train should not appear in test, validation and vice versa.
# 3. Combine the collected images together with the images of apple, orange and banana. They  are already available in the link below: https://github.com/robitussin/tensorflow_lite_projects/tree/main/images/fruits
# 4. Create and train a Convolutional Neural Network (CNN).
# 5. Save the model as **"model.tflite"**
# 6. Create a folder named **exercise_4** in your **CCDEPLRL_EXERCISES_COM222_ML** repository.
# 7. Upload the **python notebook (.ipynb)** and the **model (.tflite)** in the exercise_3 folder
#
# Deadline of submission is on **April 22, 2025**

# %% [markdown]
# ## Model

# %% [markdown]
# Import the libraries

# %%
import tensorflow as tf
import matplotlib.pyplot as plt

# %% [markdown]
# Hyperparameters: Set the image size and batch size

# %%
img_height, img_width = 32, 32
batch_size = 20

# %% [markdown]
# Split the images into train, validation and test

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
    "fruits/train",
    image_size = (img_height, img_width),
    batch_size = batch_size
)
val_ds = tf.keras.utils.image_dataset_from_directory(
    "fruits/validation",
    image_size = (img_height, img_width),
    batch_size = batch_size
)
test_ds = tf.keras.utils.image_dataset_from_directory(
    "fruits/test",
    image_size = (img_height, img_width),
    batch_size = batch_size
)
# Out:
# Found 542 files belonging to 4 classes.
# Found 77 files belonging to 4 classes.
# Found 151 files belonging to 4 classes.

# %% [markdown]
# Display sample images from the dataset

# %%
class_names = ["apple", "banana", "orange", "melon"]
plt.figure(figsize=(10,10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(4, 4, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %% [markdown]
# Create the Convolutional Neural Network Model (CNN)

# %%
model = tf.keras.Sequential(
    [
     tf.keras.layers.Rescaling(1./255),
     tf.keras.layers.Conv2D(32, 4, activation="relu"),
     tf.keras.layers.MaxPooling2D(),
     tf.keras.layers.Conv2D(32, 4, activation="relu"),
     tf.keras.layers.MaxPooling2D(),
     tf.keras.layers.Conv2D(32, 4, activation="relu"),
     tf.keras.layers.MaxPooling2D(),
     tf.keras.layers.Flatten(),
     tf.keras.layers.Dense(64, activation="relu"),
     tf.keras.layers.Dense(4)
    ]
)

# %% [markdown]
# Define the optimizer and loss function

# %%
model.compile(
    optimizer="adam",
    loss=tf.losses.SparseCategoricalCrossentropy(from_logits = True),
    metrics=['accuracy']
)

# %% [markdown]
# Train the model

# %%
model.fit(
    train_ds,
    validation_data = val_ds,
    epochs = 30
)
# Out:
# Epoch 1/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.3359 - loss: 1.3462 - val_accuracy: 0.4156 - val_loss: 1.1883
# Epoch 2/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.5674 - loss: 1.1534 - val_accuracy: 0.6883 - val_loss: 0.8297
# Epoch 3/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.6793 - loss: 0.8615 - val_accuracy: 0.6753 - val_loss: 0.8043
# Epoch 4/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.6783 - loss: 0.7709 - val_accuracy: 0.6883 - val_loss: 0.7980
# Epoch 5/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.7162 - loss: 0.6858 - val_accuracy: 0.6883 - val_loss: 0.6860
# Epoch 6/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.7641 - loss: 0.6153 - val_accuracy: 0.7662 - val_loss: 0.5666
# Epoch 7/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.7615 - loss: 0.5540 - val_accuracy: 0.7143 - val_loss: 0.5609
# Epoch 8/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.7872 - loss: 0.5655 - val_accuracy: 0.8182 - val_loss: 0.4904
# Epoch 9/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.8258 - loss: 0.4236 - val_accuracy: 0.9221 - val_loss: 0.3186
# Epoch 10/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - accuracy: 0.8668 - loss: 0.3687 - val_accuracy: 0.8182 - val_loss: 0.4667
# Epoch 11/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.8603 - loss: 0.3479 - val_accuracy: 0.9351 - val_loss: 0.3027
# Epoch 12/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.8869 - loss: 0.3088 - val_accuracy: 0.7532 - val_loss: 0.7355
# Epoch 13/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.8868 - loss: 0.3534 - val_accuracy: 0.9610 - val_loss: 0.1949
# Epoch 14/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9082 - loss: 0.2257 - val_accuracy: 0.8831 - val_loss: 0.3048
# Epoch 15/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.9062 - loss: 0.2458 - val_accuracy: 0.9740 - val_loss: 0.1460
# Epoch 16/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9281 - loss: 0.2095 - val_accuracy: 0.9351 - val_loss: 0.2129
# Epoch 17/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9450 - loss: 0.1573 - val_accuracy: 0.8701 - val_loss: 0.3199
# Epoch 18/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9414 - loss: 0.1578 - val_accuracy: 0.9610 - val_loss: 0.1419
# Epoch 19/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9632 - loss: 0.1074 - val_accuracy: 0.9610 - val_loss: 0.1975
# Epoch 20/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - accuracy: 0.8758 - loss: 0.3383 - val_accuracy: 0.9351 - val_loss: 0.2016
# Epoch 21/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.9308 - loss: 0.1833 - val_accuracy: 0.9091 - val_loss: 0.2365
# Epoch 22/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9561 - loss: 0.1128 - val_accuracy: 0.9740 - val_loss: 0.0982
# Epoch 23/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.9638 - loss: 0.1241 - val_accuracy: 0.9610 - val_loss: 0.1711
# Epoch 24/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9270 - loss: 0.2260 - val_accuracy: 0.9610 - val_loss: 0.1565
# Epoch 25/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.9643 - loss: 0.0915 - val_accuracy: 0.9740 - val_loss: 0.1106
# Epoch 26/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.9733 - loss: 0.0830 - val_accuracy: 0.9610 - val_loss: 0.1338
# Epoch 27/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9490 - loss: 0.1202 - val_accuracy: 0.9740 - val_loss: 0.0874
# Epoch 28/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9584 - loss: 0.0928 - val_accuracy: 0.9740 - val_loss: 0.1371
# Epoch 29/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9534 - loss: 0.1373 - val_accuracy: 0.9091 - val_loss: 0.1776
# Epoch 30/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.9688 - loss: 0.0726 - val_accuracy: 0.9610 - val_loss: 0.1399

# %% [markdown]
# Test the model

# %%
model.evaluate(test_ds)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9610 - loss: 0.1873
# [0.20310629904270172, 0.9602649211883545]

# %%
import numpy

plt.figure(figsize=(10,10))
for images, labels in test_ds.take(1):
  classifications = model(images)
  # print(classifications)

  for i in range(12):
    ax = plt.subplot(4, 4, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    index = numpy.argmax(classifications[i])
    plt.title("Pred: " + class_names[index] + " | Real: " + class_names[labels[i]])

# %% [markdown]
# Save the model

# %%
model.save("fruits_model.keras")
