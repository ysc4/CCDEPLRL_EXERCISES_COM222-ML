# %% [markdown]
# <a href="https://colab.research.google.com/github/robitussin/CCDEPLRL_EXERCISES/blob/main/exercise4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exercise 4

# %% [markdown]
# ## Instructions
#
#
# 1. Collect **100-200 images** of the fruit
# 2. Split the collected images for train, test and validation. Please make sure that there are no duplicate images. Images that are used in train should not appear in test, validation and vice versa.
# 3. Combine the collected images together with the images of apple, orange and banana. They  are already available in the link below: https://github.com/robitussin/tensorflow_lite_projects/tree/main/images/fruits
# 4. Create and train a Convolutional Neural Network (CNN).
# 5. Save the model as **"model.tflite"**
# 6. Create a folder named **exercise_4** in your **CCDEPLRL_EXERCISES_COM222_ML** repository.
# 7. Upload the **python notebook (.ipynb)** and the **model (.tflite)** in the exercise_3 folder
#
# Deadline of submission is on **April 22, 2025**

# %% [markdown]
# ## Model

# %% [markdown]
# Import the libraries

# %%
import tensorflow as tf
import matplotlib.pyplot as plt

# %% [markdown]
# Hyperparameters: Set the image size and batch size

# %%
img_height, img_width = 32, 32
batch_size = 20

# %% [markdown]
# Split the images into train, validation and test

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
    "fruits/train",
    image_size = (img_height, img_width),
    batch_size = batch_size
)
val_ds = tf.keras.utils.image_dataset_from_directory(
    "fruits/validation",
    image_size = (img_height, img_width),
    batch_size = batch_size
)
test_ds = tf.keras.utils.image_dataset_from_directory(
    "fruits/test",
    image_size = (img_height, img_width),
    batch_size = batch_size
)
# Out:
# Found 542 files belonging to 4 classes.
# Found 77 files belonging to 4 classes.
# Found 151 files belonging to 4 classes.

# %% [markdown]
# Display sample images from the dataset

# %%
class_names = ["apple", "banana", "orange", "melon"]
plt.figure(figsize=(10,10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(4, 4, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %% [markdown]
# Create the Convolutional Neural Network Model (CNN)

# %%
model = tf.keras.Sequential(
    [
     tf.keras.layers.Rescaling(1./255),
     tf.keras.layers.Conv2D(32, 4, activation="relu"),
     tf.keras.layers.MaxPooling2D(),
     tf.keras.layers.Conv2D(32, 4, activation="relu"),
     tf.keras.layers.MaxPooling2D(),
     tf.keras.layers.Conv2D(32, 4, activation="relu"),
     tf.keras.layers.MaxPooling2D(),
     tf.keras.layers.Flatten(),
     tf.keras.layers.Dense(64, activation="relu"),
     tf.keras.layers.Dense(4)
    ]
)

# %% [markdown]
# Define the optimizer and loss function

# %%
model.compile(
    optimizer="adam",
    loss=tf.losses.SparseCategoricalCrossentropy(from_logits = True),
    metrics=['accuracy']
)

# %% [markdown]
# Train the model

# %%
model.fit(
    train_ds,
    validation_data = val_ds,
    epochs = 30
)
# Out:
# Epoch 1/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.3311 - loss: 1.3404 - val_accuracy: 0.4286 - val_loss: 1.1495
# Epoch 2/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.5225 - loss: 1.0815 - val_accuracy: 0.6234 - val_loss: 0.9155
# Epoch 3/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.6354 - loss: 0.8551 - val_accuracy: 0.6623 - val_loss: 0.7397
# Epoch 4/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.7240 - loss: 0.6369 - val_accuracy: 0.7273 - val_loss: 0.6157
# Epoch 5/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.7266 - loss: 0.5903 - val_accuracy: 0.6753 - val_loss: 0.7054
# Epoch 6/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.7529 - loss: 0.5866 - val_accuracy: 0.8312 - val_loss: 0.3874
# Epoch 7/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.8277 - loss: 0.3757 - val_accuracy: 0.8312 - val_loss: 0.4214
# Epoch 8/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.8561 - loss: 0.3476 - val_accuracy: 0.9351 - val_loss: 0.2555
# Epoch 9/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9199 - loss: 0.2734 - val_accuracy: 0.8571 - val_loss: 0.2846
# Epoch 10/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9009 - loss: 0.2764 - val_accuracy: 0.9221 - val_loss: 0.2058
# Epoch 11/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.9255 - loss: 0.2104 - val_accuracy: 0.9351 - val_loss: 0.1768
# Epoch 12/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9281 - loss: 0.2126 - val_accuracy: 0.9221 - val_loss: 0.1870
# Epoch 13/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9405 - loss: 0.1756 - val_accuracy: 0.9610 - val_loss: 0.1157
# Epoch 14/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9179 - loss: 0.2107 - val_accuracy: 0.9740 - val_loss: 0.1254
# Epoch 15/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9445 - loss: 0.1586 - val_accuracy: 0.8701 - val_loss: 0.3985
# Epoch 16/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9322 - loss: 0.2014 - val_accuracy: 0.9740 - val_loss: 0.0993
# Epoch 17/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9709 - loss: 0.1247 - val_accuracy: 0.8831 - val_loss: 0.2610
# Epoch 18/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9517 - loss: 0.1479 - val_accuracy: 0.9481 - val_loss: 0.1751
# Epoch 19/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9677 - loss: 0.1136 - val_accuracy: 0.9351 - val_loss: 0.1774
# Epoch 20/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9673 - loss: 0.1092 - val_accuracy: 0.9351 - val_loss: 0.1073
# Epoch 21/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9682 - loss: 0.0955 - val_accuracy: 0.9351 - val_loss: 0.1753
# Epoch 22/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9687 - loss: 0.0845 - val_accuracy: 0.9740 - val_loss: 0.1319
# Epoch 23/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.8882 - loss: 0.3433 - val_accuracy: 0.9221 - val_loss: 0.2143
# Epoch 24/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9659 - loss: 0.1387 - val_accuracy: 0.9740 - val_loss: 0.1048
# Epoch 25/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9805 - loss: 0.0808 - val_accuracy: 0.9740 - val_loss: 0.0705
# Epoch 26/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9656 - loss: 0.0816 - val_accuracy: 0.9610 - val_loss: 0.1067
# Epoch 27/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - accuracy: 0.9829 - loss: 0.0451 - val_accuracy: 0.9870 - val_loss: 0.0698
# Epoch 28/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9747 - loss: 0.0567 - val_accuracy: 0.9610 - val_loss: 0.0978
# Epoch 29/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9983 - loss: 0.0332 - val_accuracy: 0.9221 - val_loss: 0.2074
# Epoch 30/30
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9899 - loss: 0.0467 - val_accuracy: 0.9481 - val_loss: 0.1699

# %% [markdown]
# Test the model

# %%
model.evaluate(test_ds)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9623 - loss: 0.1834
# [0.19289717078208923, 0.9536423683166504]

# %%
import numpy

plt.figure(figsize=(10,10))
for images, labels in test_ds.take(1):
  classifications = model(images)
  # print(classifications)

  for i in range(12):
    ax = plt.subplot(4, 4, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    index = numpy.argmax(classifications[i])
    plt.title("Pred: " + class_names[index] + " | Real: " + class_names[labels[i]])
# Out:
# 2025-04-22 16:48:40.088695: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %% [markdown]
# Save the model

# %%
model.save("fruits_model.keras")
